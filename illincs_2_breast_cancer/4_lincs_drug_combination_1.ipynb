# %%
import pandas as pd
import os
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt

# %% [markdown]
# # Read files for drug combiantion

# %%
# read the expression data from every file and combine them together
file_path = '/Users/yanlixu/Desktop/pingan/合作/CDK12/220608/LINSCP_for_drug_combinations'
files = os.listdir(file_path)

file_list = []
gene_list = []
diff_value_list = []

for file in files:
    if os.path.isfile(os.path.join(file_path, file)):
        file_list.append(file.replace(' .csv', ''))
        if file == 'LINCSCP_30149 .csv':
            gene_list = data['Name_GeneSymbol'].tolist()       
        data = pd.read_csv(os.path.join(file_path, file))
        diff_value_list.append(data['Value_LogDiffExp'].tolist())
        
diff_value_df = pd.DataFrame(diff_value_list)
diff_value_df = diff_value_df.transpose()

diff_value_df.columns = file_list
diff_value_df.index = gene_list
diff_value_df
# Out:
#          LINCSCP_135119  LINCSCP_132633  LINCSCP_132799  LINCSCP_138394  \
# AARS          -1.051640        0.184166       -0.669090       -2.908100
# ABCF1         -0.354414        0.262992       -1.277380       -0.591225
# ABL1          -1.786470        0.815821       -1.572860       -0.941629
# ACAA1         -0.125800        1.565410        0.773275        0.584377
# ACAT2         -2.474760       -1.200910       -2.292480       -4.506790
# ...                 ...             ...             ...             ...
# TXLNA         -0.922860        0.608168        0.604441        1.342910
# SPRED2         0.936911       -1.107080       -0.075491        0.474223
# EML3           1.259370       -0.218833       -1.154410        0.436730
# TMEM110       -0.335950       -0.054169       -0.715620       -1.218830
# FAM69A        -0.220236       -0.780482        0.145059        0.575219
#
#          LINCSCP_139585  LINCSCP_35854  LINCSCP_30569  LINCSCP_36517  \
# ...

# %%
diff_value_df.columns
# Out:
# Index(['LINCSCP_135119', 'LINCSCP_132633', 'LINCSCP_132799', 'LINCSCP_138394',
#        'LINCSCP_139585', 'LINCSCP_35854', 'LINCSCP_30569', 'LINCSCP_36517',
#        'LINCSCP_135676', 'LINCSCP_142931',
#        ...
#        'LINCSCP_33151', 'LINCSCP_139379', 'LINCSCP_131876', 'LINCSCP_36580',
#        'LINCSCP_33106', 'LINCSCP_34293', 'LINCSCP_33805', 'LINCSCP_139791',
#        'LINCSCP_33043', 'LINCSCP_140827'],
#       dtype='object', length=544)

# %% [markdown]
# # only compare the intersection genes of *top up/down regulated genes from disease* and *978 genes from purturbanges*

# %%
# read top up and down regulated genes data
top_genes_data = pd.read_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220608/1_breast_cancer_20220608.xlsx', sheet_name='top_640_genes')

top_genes_data = top_genes_data.set_index('Name_GeneSymbol')
top_genes_data
# Out:
#                            PROBE  ID_geneid  \
# Name_GeneSymbol
# ESR1             ENSG00000091831       2099
# GRB7             ENSG00000141738       2886
# STARD3           ENSG00000131748      10948
# BCL2             ENSG00000171791        596
# CCDC170          ENSG00000120262      80129
# ...                          ...        ...
# MST1             ENSG00000173531       4485
# ULBP2            ENSG00000131015      80328
# CRISPLD1         ENSG00000121005      83690
# PLCB4            ENSG00000101333       5332
# DDC              ENSG00000132437       1644
#
#                                                        Description  \
# Name_GeneSymbol
# ESR1                                           estrogen receptor 1
# GRB7                        growth factor receptor-bound protein 7
# STARD3           StAR-related lipid transfer (START) domain con...
# BCL2                                         B-cell CLL/lymphoma 2
# ...

# %%
# merge two dataframe
df_merged = pd.merge(diff_value_df, top_genes_data[['Value_LogDiffExp']], left_index=True, right_index=True)
df_merged.rename(columns={'Value_LogDiffExp': 'breast_cancer_reverse_gene_expression'}, inplace=True)
df_merged
# Out:
#         LINCSCP_135119  LINCSCP_132633  LINCSCP_132799  LINCSCP_138394  \
# AURKA        -1.551470       -0.150657       -0.080711       -2.488470
# AURKB        -2.158650        0.167131        0.078657       -1.416590
# BCL2          0.118995        0.639572        0.366932        0.600968
# BIRC5        -2.514860        0.103394       -0.111482       -2.101980
# BUB1B        -1.367600       -0.333383       -0.180426       -0.643180
# CCNA2        -2.237130       -0.073553        0.037892       -1.593790
# CCNB1        -1.505030       -0.382608        0.049830       -3.522990
# CCNB2        -2.913710       -1.588320       -0.119828       -2.945360
# CCNE2         0.096956       -0.391006        0.158480        0.843196
# CDC20        -3.933380        0.466745        0.004829       -2.301830
# CDC25A       -1.018540        0.103823        0.020438       -0.324055
# CDC25B        1.196870        0.633913       -0.171035       -1.436540
# ...

# %% [markdown]
# # Calculation 1: compounds compare with 'LINCSCP_32475'

# %%
# if the expression value same direction (both upregulated or both down regulated) with LINCSCP_32475, then 1; else 0
def compare(col1, col2):
    result = col1 * col2
    return [1 if res > 0 else 0 for res in result] 

df_merged_1 = df_merged.drop(columns=['breast_cancer_reverse_gene_expression'])
result_1 = []
for col in df_merged_1.columns.tolist():
    result_1.append(compare(df_merged_1['LINCSCP_30538'], df_merged_1[col]))
result_1_df = pd.DataFrame(result_1, columns = df_merged_1.index.tolist())
result_1_df.index = df_merged_1.columns
result_1_df
# Out:
#                 AURKA  AURKB  BCL2  BIRC5  BUB1B  CCNA2  CCNB1  CCNB2  CCNE2  \
# LINCSCP_135119      1      1     1      1      1      1      1      1      0
# LINCSCP_132633      1      0     1      0      1      1      1      1      1
# LINCSCP_132799      1      0     1      1      1      0      0      1      0
# LINCSCP_138394      1      1     1      1      1      1      1      1      0
# LINCSCP_139585      1      1     1      1      1      1      1      1      1
# ...               ...    ...   ...    ...    ...    ...    ...    ...    ...
# LINCSCP_34293       1      1     0      1      1      1      1      1      1
# LINCSCP_33805       1      1     0      1      0      1      1      1      1
# LINCSCP_139791      1      1     0      1      1      1      1      1      1
# LINCSCP_33043       1      1     1      1      1      1      1      1      1
# LINCSCP_140827      1      1     0      1      1      1      1      1      1
#
# ...

# %%
ax = sns.clustermap(result_1_df, standard_scale=1, cmap="vlag")
plt.show()
# Out:
# /opt/anaconda3/envs/deepchem_py37/lib/python3.7/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# how many genes same direction(1s) with LINCSCP_30538

result_1_df['sum_of_same_dir_genes'] = result_1_df.sum(axis=1)
result_1_df['sum_of_same_dir_genes_rate'] = round(result_1_df['sum_of_same_dir_genes']/41, 2)
result_1_df
# Out:
#                 AURKA  AURKB  BCL2  BIRC5  BUB1B  CCNA2  CCNB1  CCNB2  CCNE2  \
# LINCSCP_135119      1      1     1      1      1      1      1      1      0
# LINCSCP_132633      1      0     1      0      1      1      1      1      1
# LINCSCP_132799      1      0     1      1      1      0      0      1      0
# LINCSCP_138394      1      1     1      1      1      1      1      1      0
# LINCSCP_139585      1      1     1      1      1      1      1      1      1
# ...               ...    ...   ...    ...    ...    ...    ...    ...    ...
# LINCSCP_34293       1      1     0      1      1      1      1      1      1
# LINCSCP_33805       1      1     0      1      0      1      1      1      1
# LINCSCP_139791      1      1     0      1      1      1      1      1      1
# LINCSCP_33043       1      1     1      1      1      1      1      1      1
# LINCSCP_140827      1      1     0      1      1      1      1      1      1
#
# ...

# %% [markdown]
# # Calculation 2: compounds compare with reverse_of_breast_cancer

# %%
# if the expression value same direction (both upregulated or both down regulated) with reverse_of_breast_cancer, then 1; else 0


def compare(col1, col2):
    result = col1 * col2
    return [1 if res > 0 else 0 for res in result] 

#df_merged_1 = df_merged.drop(columns=['breast_cancer_reverse_gene_expression'])
result_2 = []
for col in df_merged.columns.tolist():
    result_2.append(compare(df_merged['breast_cancer_reverse_gene_expression'], df_merged[col]))
result_2_df = pd.DataFrame(result_2, columns = df_merged.index.tolist())
result_2_df.index = df_merged.columns
result_2_df
# Out:
#                                        AURKA  AURKB  BCL2  BIRC5  BUB1B  \
# LINCSCP_135119                             1      1     1      1      1
# LINCSCP_132633                             1      0     1      0      1
# LINCSCP_132799                             1      0     1      1      1
# LINCSCP_138394                             1      1     1      1      1
# LINCSCP_139585                             1      1     1      1      1
# ...                                      ...    ...   ...    ...    ...
# LINCSCP_33805                              1      1     0      1      0
# LINCSCP_139791                             1      1     0      1      1
# LINCSCP_33043                              1      1     1      1      1
# LINCSCP_140827                             1      1     0      1      1
# breast_cancer_reverse_gene_expression      1      1     1      1      1
#
#                                        CCNA2  CCNB1  CCNB2  CCNE2  CDC20  ...  \
# ...

# %%
ax = sns.clustermap(result_2_df, standard_scale=1, cmap="vlag")
plt.show()
# Out:
# /opt/anaconda3/envs/deepchem_py37/lib/python3.7/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# how many same direction with reverse_of_breast_cancer

result_2_df['sum_of_same_dir_genes'] = result_2_df.sum(axis=1)
result_2_df['sum_of_same_dir_genes_rate'] = round(result_2_df['sum_of_same_dir_genes']/41, 2)
result_2_df
# Out:
#                                        AURKA  AURKB  BCL2  BIRC5  BUB1B  \
# LINCSCP_135119                             1      1     1      1      1
# LINCSCP_132633                             1      0     1      0      1
# LINCSCP_132799                             1      0     1      1      1
# LINCSCP_138394                             1      1     1      1      1
# LINCSCP_139585                             1      1     1      1      1
# ...                                      ...    ...   ...    ...    ...
# LINCSCP_33805                              1      1     0      1      0
# LINCSCP_139791                             1      1     0      1      1
# LINCSCP_33043                              1      1     1      1      1
# LINCSCP_140827                             1      1     0      1      1
# breast_cancer_reverse_gene_expression      1      1     1      1      1
#
#                                        CCNA2  CCNB1  CCNB2  CCNE2  CDC20  ...  \
# ...

# %% [markdown]
# # merge two dataframe

# %%
df_final = pd.merge(result_1_df[['sum_of_same_dir_genes_rate']], result_2_df[['sum_of_same_dir_genes_rate']], left_index=True, right_index=True)
df_final.rename(columns={'sum_of_same_dir_genes_rate_x': 'percentage_of_same_direction_genes_w_30538', 'sum_of_same_dir_genes_rate_y': 'percentage_of_reverse_direction_genes_w_breast_cancer'}, inplace=True)

df_final['rank_score'] = round(df_final['percentage_of_reverse_direction_genes_w_breast_cancer']/df_final['percentage_of_same_direction_genes_w_30538'], 2)

# %%
df_final = df_final.sort_values(by=['rank_score'], ascending=False)
df_final
# Out:
#                 percentage_of_same_direction_genes_w_30538  \
# LINCSCP_239045                                        0.59
# LINCSCP_32637                                         0.63
# LINCSCP_238822                                        0.44
# LINCSCP_30490                                         0.51
# LINCSCP_35280                                         0.51
# ...                                                    ...
# LINCSCP_140826                                        0.85
# LINCSCP_139056                                        0.90
# LINCSCP_34475                                         0.85
# LINCSCP_137054                                        0.95
# LINCSCP_140827                                        0.90
#
#                 percentage_of_reverse_direction_genes_w_breast_cancer  \
# LINCSCP_239045                                               0.73
# LINCSCP_32637                                                0.78
# ...

# %%
# get chemical info

chem_info = pd.read_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220608/1_breast_cancer_20220608.xlsx', sheet_name='selected_connect_chems_642')
chem_info = chem_info.set_index('SignatureId')
chem_info
# Out:
#                           Perturbagen    GeneTargets Concentration CellLine  \
# SignatureId
# LINCSCP_30538              BMS-536924          IGF1R          10uM     MCF7
# LINCSCP_33844           BRD-K32568627            NaN          10uM     MCF7
# LINCSCP_132639            936890-98-1           MTOR        0.12uM     MCF7
# LINCSCP_30683                  PIK 90            NaN          10uM     MCF7
# LINCSCP_32422              WYE 125132           MTOR          10uM     MCF7
# ...                               ...            ...           ...      ...
# LINCSCP_31628   Triazine Scaffold, 51            NaN          10uM     MCF7
# LINCSCP_37872              Fedratinib      FLT3|JAK2          10uM     MCF7
# LINCSCP_139056          Protriptyline  SLC6A2|SLC6A4          10uM     MCF7
# LINCSCP_37700              ST-4062971            NaN           3uM     MCF7
# LINCSCP_32593                XMD-1527            NaN          10uM     MCF7
#
# ...

# %%
df_final_w_chem_info = pd.merge(df_final, chem_info, left_index=True, right_index=True)
df_final_w_chem_info
# Out:
#                 percentage_of_same_direction_genes_w_30538  \
# LINCSCP_239045                                        0.59
# LINCSCP_32637                                         0.63
# LINCSCP_238822                                        0.44
# LINCSCP_30490                                         0.51
# LINCSCP_35280                                         0.51
# ...                                                    ...
# LINCSCP_140826                                        0.85
# LINCSCP_139056                                        0.90
# LINCSCP_34475                                         0.85
# LINCSCP_137054                                        0.95
# LINCSCP_140827                                        0.90
#
#                 percentage_of_reverse_direction_genes_w_breast_cancer  \
# LINCSCP_239045                                               0.73
# LINCSCP_32637                                                0.78
# ...

# %%
df_final_w_chem_info.to_csv('/Users/yanlixu/Desktop/pingan/合作/CDK12/220608/test3.csv')

# %%
sns.scatterplot(data=df_final_w_chem_info, x="percentage_of_same_direction_genes_w_30538", y="percentage_of_reverse_direction_genes_w_breast_cancer")
plt.show()

# %%
df_final_w_chem_info_sorted = df_final_w_chem_info.sort_values(by='rank_score', ascending=False)
df_final_w_chem_info_sorted
# Out:
#                 percentage_of_same_direction_genes_w_30538  \
# LINCSCP_239045                                        0.59
# LINCSCP_32637                                         0.63
# LINCSCP_238822                                        0.44
# LINCSCP_30490                                         0.51
# LINCSCP_35280                                         0.51
# ...                                                    ...
# LINCSCP_140826                                        0.85
# LINCSCP_139056                                        0.90
# LINCSCP_34475                                         0.85
# LINCSCP_137054                                        0.95
# LINCSCP_140827                                        0.90
#
#                 percentage_of_reverse_direction_genes_w_breast_cancer  \
# LINCSCP_239045                                               0.73
# LINCSCP_32637                                                0.78
# ...

# %%
df_final_w_chem_info_sorted_sub = df_final_w_chem_info_sorted.loc[['LINCSCP_30538','LINCSCP_239045','LINCSCP_32637','LINCSCP_238822', 'LINCSCP_35280', 'LINCSCP_135235', 'LINCSCP_36981', 'LINCSCP_32422', 'LINCSCP_132724', 'LINCSCP_143133']]

x = df_final_w_chem_info_sorted_sub['percentage_of_same_direction_genes_w_30538'].values
y = df_final_w_chem_info_sorted_sub['percentage_of_reverse_direction_genes_w_breast_cancer'].values
samples = df_final_w_chem_info_sorted_sub['Perturbagen'].tolist()

fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(x, y)

ax.set_xlabel('percentage_of_same_direction_genes_w_30538', fontsize=14)
ax.set_ylabel('percentage_of_reverse_direction_genes_w_breast_cancer', fontsize=14)
ax.set_title('Top compounds combined with LINCSCP_30538', fontsize=18)

for i, txt in enumerate(samples):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='red')
plt.show()

# %%
df_final_sub = df_final.loc[['LINCSCP_30538','LINCSCP_239045','LINCSCP_32637','LINCSCP_238822', 'LINCSCP_35280', 'LINCSCP_135235', 'LINCSCP_36981', 'LINCSCP_32422', 'LINCSCP_132724', 'LINCSCP_143133']]

x = df_final_sub['percentage_of_same_direction_genes_w_30538'].values
y = df_final_sub['percentage_of_reverse_direction_genes_w_breast_cancer'].values
samples = df_final_sub.index.tolist()

fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(x, y)

ax.set_xlabel('percentage_of_same_direction_genes_w_30538', fontsize=14)
ax.set_ylabel('percentage_of_reverse_direction_genes_w_breast_cancer', fontsize=14)
ax.set_title('Top compounds combined with LINCSCP_30538', fontsize=18)

for i, txt in enumerate(samples):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='red')
plt.show()

# %%
# temp
import pandas as pd

data1 = pd.read_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220608/1_breast_cancer_20220608.xlsx', sheet_name='top_640_genes')
data2 = pd.read_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220608/1_breast_cancer_20220608.xlsx', sheet_name='KEGG_info_of_top_640_genes')

df_merged = data1.merge(data2, left_on='ID_geneid', right_on='ncbi_genes')
df_merged = df_merged.drop_duplicates()
df_merged.to_csv('/Users/yanlixu/Desktop/test/test12345.csv')
