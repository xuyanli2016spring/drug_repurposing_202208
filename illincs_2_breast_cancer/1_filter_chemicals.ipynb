# %%
import pandas as pd

# %%
data = pd.read_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220608/1_breast_cancer_20220608.xlsx', sheet_name='connect_chems_14337')
data
# Out:
#           SignatureId    Perturbagen  \
# 0       LINCSCP_30538     BMS-536924
# 1       LINCSCP_33844  BRD-K32568627
# 2      LINCSCP_132639    936890-98-1
# 3      LINCSCP_116257      CGP 60474
# 4       LINCSCP_64538      Tretinoin
# ...               ...            ...
# 14332  LINCSCP_247490  BRD-K10662075
# 14333  LINCSCP_130275       AZD-5438
# 14334   LINCSCP_67856     Wortmannin
# 14335    LINCSCP_5915     Nicorandil
# 14336  LINCSCP_146329     Vandetanib
#
#                                              GeneTargets Concentration  \
# 0                                                  IGF1R          10uM
# 1                                                    NaN          10uM
# 2                                                   MTOR        0.12uM
# 3                                                   CDK1        0.12uM
# 4                                    RARA|RARB|RARG|RORB           1uM
# ...                                                  ...           ...
# 14332                                                NaN           5uM
# 14333  CDK1|CDK10|CDK11B|CDK12|CDK13|CDK14|CDK15|CDK1...        0.37uM
# 14334                                 PIK3CA|PIK3CG|PLK1          10uM
# 14335                                                NaN          10uM
# 14336  EGFR|EPHA1|EPHA10|EPHA2|EPHA3|EPHA4|EPHA5|EPHA...          10uM
#
#       CellLine           Tissue Time  is_exemplar  Concordance    pValue  \
# 0         MCF7           breast  24h          1.0     0.679659  0.000001
# 1         MCF7           breast  24h          0.0     0.674035  0.000001
# 2         MCF7           breast  24h          NaN     0.673512  0.000001
# 3         HT29  large intestine  24h          NaN     0.660094  0.000003
# 4         VCAP         prostate  48h          0.0    -0.656580  0.000003
# ...        ...              ...  ...          ...          ...       ...
# 14332     MCF7           breast  24h          1.0     0.315430  0.044549
# 14333    LNCAP         prostate   3h          NaN     0.315414  0.044561
# 14334      PC3         prostate   6h          0.0     0.315401  0.044570
# 14335     A549             lung   6h          1.0     0.315385  0.044581
# 14336   MNEU.E              NaN  24h          NaN    -0.315379  0.044586
#
#        nGenes
# 0          41
# 1          41
# 2          41
# 3          41
# 4          41
# ...       ...
# 14332      41
# 14333      41
# 14334      41
# 14335      41
# 14336      41
#
# [14337 rows x 11 columns]

# %%
data_selected = data[(data['CellLine']=='MCF7') & (data['Concordance'] > 0.3) & (data['pValue'] < 0.01)]
data_selected
# Out:
#          SignatureId            Perturbagen    GeneTargets Concentration  \
# 0      LINCSCP_30538             BMS-536924          IGF1R          10uM
# 1      LINCSCP_33844          BRD-K32568627            NaN          10uM
# 2     LINCSCP_132639            936890-98-1           MTOR        0.12uM
# 5      LINCSCP_30683                 PIK 90            NaN          10uM
# 6      LINCSCP_32422             WYE 125132           MTOR          10uM
# ...              ...                    ...            ...           ...
# 4653   LINCSCP_31628  Triazine Scaffold, 51            NaN          10uM
# 4654   LINCSCP_37872             Fedratinib      FLT3|JAK2          10uM
# 4663  LINCSCP_139056          Protriptyline  SLC6A2|SLC6A4          10uM
# 4671   LINCSCP_37700             ST-4062971            NaN           3uM
# 4686   LINCSCP_32593               XMD-1527            NaN          10uM
#
#      CellLine  Tissue Time  is_exemplar  Concordance    pValue  nGenes
# 0        MCF7  breast  24h          1.0     0.679659  0.000001      41
# 1        MCF7  breast  24h          0.0     0.674035  0.000001      41
# 2        MCF7  breast  24h          NaN     0.673512  0.000001      41
# 5        MCF7  breast  24h          1.0     0.649801  0.000004      41
# 6        MCF7  breast  24h          0.0     0.649405  0.000004      41
# ...       ...     ...  ...          ...          ...       ...     ...
# 4653     MCF7  breast  24h          1.0     0.398284  0.009906      41
# 4654     MCF7  breast  24h          0.0     0.398282  0.009907      41
# 4663     MCF7  breast  24h          NaN     0.398163  0.009931      41
# 4671     MCF7  breast  24h          0.0     0.398094  0.009945      41
# 4686     MCF7  breast  24h          0.0     0.397917  0.009981      41
#
# [642 rows x 11 columns]

# %%
#data_selected.to_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220608/test.xlsx', sheet_name='selected_con_chems_6442')
