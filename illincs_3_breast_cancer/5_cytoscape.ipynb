# %%
import pandas as pd
import os
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt

# %% [markdown]
# # chemical regulate genes

# %%
# read the expression data from every file and combine them together
file_path = '/Users/yanlixu/Desktop/pingan/合作/CDK12/220616/LINSCP_for_drug_combinations'
files = os.listdir(file_path)

file_list = []
gene_list = []
diff_value_list = []

for file in files:
    if os.path.isfile(os.path.join(file_path, file)):
        file_list.append(file.replace(' .csv', ''))
        if file == 'LINCSCP_30171 .csv':
            gene_list = data['Name_GeneSymbol'].tolist()       
        data = pd.read_csv(os.path.join(file_path, file))
        diff_value_list.append(data['Value_LogDiffExp'].tolist())
        
diff_value_df = pd.DataFrame(diff_value_list)
diff_value_df = diff_value_df.transpose()

diff_value_df.columns = file_list
diff_value_df.index = gene_list
diff_value_df
# Out:
#          LINCSCP_38362  LINCSCP_34341  LINCSCP_143009  LINCSCP_32915  \
# AARS          1.494280      -0.619955        4.019460      -2.331810
# ABCF1        -1.079000       0.331871       -0.869827      -2.765140
# ABL1         -2.922490      -1.064530       -1.657750      -1.158990
# ACAA1         0.546718      -0.595667        1.216550      -0.091681
# ACAT2        -0.059628       0.649373       -2.380550       0.433265
# ...                ...            ...             ...            ...
# TXLNA         1.076610      -0.288040       -0.283192      -1.379400
# SPRED2        0.163661       0.161295       -0.167704       0.846945
# EML3          0.070458      -0.986843       -1.313710      -0.511510
# TMEM110      -1.040950       0.253314       -1.342180       0.459366
# FAM69A        0.027207       0.853779       -2.718890       0.410731
#
#          LINCSCP_30882  LINCSCP_32041  LINCSCP_30343  LINCSCP_134030  \
# AARS         -0.063457      -4.853260       0.635163       -2.613470
# ABCF1         0.153361       0.990553       0.436411       -0.115094
# ABL1         -0.280789      -1.238150       0.883352       -1.196040
# ACAA1         0.586592       0.293339      -0.100985       -0.687410
# ACAT2         0.409297      -2.025530       0.289256       -0.413886
# ...                ...            ...            ...             ...
# TXLNA         0.105837       0.584791      -0.095763        1.200010
# SPRED2        0.035816      -1.679320       0.583823        0.548437
# EML3          0.375487       1.721950       1.640430       -0.792332
# TMEM110       0.457051       4.215620      -0.798682       -0.460531
# FAM69A        0.507479      -1.213580      -0.274027        0.117494
#
#          LINCSCP_138013  LINCSCP_30986  ...  LINCSCP_38863  LINCSCP_37738  \
# AARS           -1.33500      -0.343550  ...       -0.64210       0.589441
# ABCF1           0.09200       0.867296  ...       -0.47790      -1.014340
# ABL1           -1.34635      -0.225222  ...       -4.68355      -0.174940
# ACAA1          -2.61995       0.108072  ...        3.88960       0.040737
# ACAT2           1.85050       0.904678  ...        1.39060      -0.500403
# ...                 ...            ...  ...            ...            ...
# TXLNA          -1.26715      -0.834586  ...       -4.34090      -0.122994
# SPRED2         -0.11865       0.395441  ...        0.98630      -0.669213
# EML3           -0.56980      -0.736650  ...        0.30320       0.213313
# TMEM110         0.42335      -0.845484  ...        0.73525      -0.888186
# FAM69A          0.83545      -0.192166  ...        0.78975      -0.800063
#
#          LINCSCP_138138  LINCSCP_140489  LINCSCP_241019  LINCSCP_32717  \
# AARS           2.275850        0.317485        0.299537      -0.053473
# ABCF1          1.184140        0.140167       -1.243110       0.307844
# ABL1           0.401152        0.459429       -0.699727       0.388227
# ACAA1          0.228642        0.735920        0.177715       0.295074
# ACAT2         -0.585729        1.071690       -0.099666      -0.434428
# ...                 ...             ...             ...            ...
# TXLNA         -0.684713        0.279481       -0.720292       1.063460
# SPRED2        -2.169700        0.808282       -0.118622       0.275208
# EML3           0.105797        0.037861       -0.675822       0.762196
# TMEM110       -0.288151        0.236437        0.045929      -0.023631
# FAM69A         0.012822        0.910366        0.427058      -0.349044
#
#          LINCSCP_138883  LINCSCP_37329  LINCSCP_141670  LINCSCP_240171
# AARS          -8.767110       0.926990       -1.721910       -1.147110
# ABCF1          2.176350       0.208830        0.017453        0.499426
# ABL1          -1.595640      -3.406730        0.017226       -1.449620
# ACAA1          3.775060      -0.225089        0.730956        0.130912
# ACAT2          0.624442      -5.543650        0.607123       -0.082746
# ...                 ...            ...             ...             ...
# TXLNA          5.526860      -0.075133       -0.397316        0.573336
# SPRED2         3.228020      -0.687351        0.855661        0.731780
# EML3           2.179590       0.117983        0.021021        0.377983
# TMEM110        3.798570       2.154920        0.379698        0.597835
# FAM69A         4.756390      -1.160400        1.453300        0.605177
#
# [978 rows x 429 columns]

# %%
#diff_value_df.to_csv('/Users/yanlixu/Desktop/pingan/合作/CDK12/220608/test5.csv')

# %%
fout = open('test6.txt', 'w')
for index, row in diff_value_df.iterrows():
    for col in diff_value_df.columns:
        fout.write(index + '\t' + col + '\t' + str(row[col]) + '\t' + 'regulate' + '\n')

# %% [markdown]
# # chemical-target

# %%
data = pd.read_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220616/1_breast_cancer_20220616.xlsx', sheet_name = 'chemical_target')
data
# Out:
#           SignatureId                                        Perturbagen  \
# 0       LINCSCP_12759  4,11-Diethyl-4,9-dihydroxy-1H-pyrano[3',4':6,7...
# 1       LINCSCP_29260                                        Perhexiline
# 2      LINCSCP_111268                                             WZ3105
# 3       LINCSCP_41821                                             IN1541
# 4       LINCSCP_51043                                         Teniposide
# ...               ...                                                ...
# 14332   LINCSCP_42591                              Mycophenolate Mofetil
# 14333    LINCSCP_4675                                           AC1Q6JJ5
# 14334   LINCSCP_96669                                           MLN-8054
# 14335  LINCSCP_116171                                         Tozasertib
# 14336  LINCSCP_203983                                    SPECTRUM_001131
#
#                                 GeneTargets
# 0                                      TOP1
# 1                                CPT1A|CPT2
# 2                     CLK2|CSNK1E|FLT3|ULK1
# 3                                    PRKAA1
# 4                                     TOP2A
# ...                                     ...
# 14332                         IMPDH1|IMPDH2
# 14333                                 TOP2A
# 14334                                 AURKA
# 14335  ABL1|AURKA|AURKB|AURKC|BCR|FLT3|JAK2
# 14336                                   NaN
#
# [14337 rows x 3 columns]

# %%
data_final = data.set_index(['SignatureId', 'Perturbagen']).apply(lambda x: x.str.split('|').explode()).reset_index().dropna().drop_duplicates()
data_final
# Out:
#           SignatureId                                        Perturbagen  \
# 0       LINCSCP_12759  4,11-Diethyl-4,9-dihydroxy-1H-pyrano[3',4':6,7...
# 1       LINCSCP_29260                                        Perhexiline
# 2       LINCSCP_29260                                        Perhexiline
# 3      LINCSCP_111268                                             WZ3105
# 4      LINCSCP_111268                                             WZ3105
# ...               ...                                                ...
# 45612  LINCSCP_116171                                         Tozasertib
# 45613  LINCSCP_116171                                         Tozasertib
# 45614  LINCSCP_116171                                         Tozasertib
# 45615  LINCSCP_116171                                         Tozasertib
# 45616  LINCSCP_116171                                         Tozasertib
#
#       GeneTargets
# 0            TOP1
# 1           CPT1A
# 2            CPT2
# 3            CLK2
# 4          CSNK1E
# ...           ...
# 45612       AURKB
# 45613       AURKC
# 45614         BCR
# 45615        FLT3
# 45616        JAK2
#
# [39959 rows x 3 columns]

# %%
data_final.to_csv('test7.csv')

# %% [markdown]
# # gene pathway, BP, CC, MF

# %%
data = pd.read_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220616/1_breast_cancer_20220616.xlsx', sheet_name='DAVID')
bp = data[data['Category']== 'GOTERM_BP_DIRECT']
cc = data[data['Category']== 'GOTERM_CC_DIRECT']
mf = data[data['Category']== 'GOTERM_MF_DIRECT']
pthw = data[data['Category']== 'KEGG_PATHWAY']

# %%
bp_final = bp[['Category', 'Term', 'Genes']].set_index(['Category', 'Term']).apply(lambda x: x.str.split(',').explode()).reset_index().dropna().drop_duplicates()
bp_final['bp'] = bp_final['Term'].apply(lambda x: x.split('~')[1])
bp_final
# Out:
#               Category                                             Term  \
# 0     GOTERM_BP_DIRECT                          GO:0001525~angiogenesis
# 1     GOTERM_BP_DIRECT                          GO:0001525~angiogenesis
# 2     GOTERM_BP_DIRECT                          GO:0001525~angiogenesis
# 3     GOTERM_BP_DIRECT                          GO:0001525~angiogenesis
# 4     GOTERM_BP_DIRECT                          GO:0001525~angiogenesis
# ...                ...                                              ...
# 1842  GOTERM_BP_DIRECT  GO:0035914~skeletal muscle cell differentiation
# 1843  GOTERM_BP_DIRECT  GO:0035914~skeletal muscle cell differentiation
# 1844  GOTERM_BP_DIRECT  GO:0035914~skeletal muscle cell differentiation
# 1845  GOTERM_BP_DIRECT  GO:0035914~skeletal muscle cell differentiation
# 1846  GOTERM_BP_DIRECT  GO:0035914~skeletal muscle cell differentiation
#
#         Genes                                    bp
# 0       ROBO4                          angiogenesis
# 1       RAMP2                          angiogenesis
# 2       FOXC1                          angiogenesis
# 3       RAMP3                          angiogenesis
# 4       ECSCR                          angiogenesis
# ...       ...                                   ...
# 1842      HLF  skeletal muscle cell differentiation
# 1843    SMYD1  skeletal muscle cell differentiation
# 1844     KRAS  skeletal muscle cell differentiation
# 1845   HIVEP3  skeletal muscle cell differentiation
# 1846     SOX8  skeletal muscle cell differentiation
#
# [1847 rows x 4 columns]

# %%
bp_final.to_csv('bp.csv')

# %%
cc_final = cc[['Category', 'Term', 'Genes']].set_index(['Category', 'Term']).apply(lambda x: x.str.split(',').explode()).reset_index().dropna().drop_duplicates()
cc_final['cc'] = cc_final['Term'].apply(lambda x: x.split('~')[1])
cc_final
# Out:
#               Category                             Term    Genes  \
# 0     GOTERM_CC_DIRECT  GO:0005576~extracellular region    HPSE2
# 1     GOTERM_CC_DIRECT  GO:0005576~extracellular region    PROS1
# 2     GOTERM_CC_DIRECT  GO:0005576~extracellular region     CSN3
# 3     GOTERM_CC_DIRECT  GO:0005576~extracellular region     CSN2
# 4     GOTERM_CC_DIRECT  GO:0005576~extracellular region     FGF1
# ...                ...                              ...      ...
# 1609  GOTERM_CC_DIRECT           GO:0005874~microtubule   DPYSL2
# 1610  GOTERM_CC_DIRECT           GO:0005874~microtubule      DCX
# 1611  GOTERM_CC_DIRECT           GO:0005874~microtubule   KIF21A
# 1612  GOTERM_CC_DIRECT           GO:0005874~microtubule   KIF20A
# 1613  GOTERM_CC_DIRECT           GO:0005874~microtubule   MAPRE1
#
#                         cc
# 0     extracellular region
# 1     extracellular region
# 2     extracellular region
# 3     extracellular region
# 4     extracellular region
# ...                    ...
# 1609           microtubule
# 1610           microtubule
# 1611           microtubule
# 1612           microtubule
# 1613           microtubule
#
# [1614 rows x 4 columns]

# %%
cc_final.to_csv('cc.csv')

# %%
mf_final = mf[['Category', 'Term', 'Genes']].set_index(['Category', 'Term']).apply(lambda x: x.str.split(',').explode()).reset_index().dropna().drop_duplicates()
mf_final['mf'] = mf_final['Term'].apply(lambda x: x.split('~')[1])
mf_final
# Out:
#              Category                           Term   Genes  \
# 0    GOTERM_MF_DIRECT    GO:0005178~integrin binding    TNXB
# 1    GOTERM_MF_DIRECT    GO:0005178~integrin binding     DST
# 2    GOTERM_MF_DIRECT    GO:0005178~integrin binding    CD81
# 3    GOTERM_MF_DIRECT    GO:0005178~integrin binding   LAMA3
# 4    GOTERM_MF_DIRECT    GO:0005178~integrin binding   LTBP4
# ..                ...                            ...     ...
# 624  GOTERM_MF_DIRECT  GO:0005516~calmodulin binding   MYO1B
# 625  GOTERM_MF_DIRECT  GO:0005516~calmodulin binding   MYH11
# 626  GOTERM_MF_DIRECT  GO:0005516~calmodulin binding    NOS1
# 627  GOTERM_MF_DIRECT  GO:0005516~calmodulin binding   CAMK1
# 628  GOTERM_MF_DIRECT  GO:0005516~calmodulin binding   SCN5A
#
#                      mf
# 0      integrin binding
# 1      integrin binding
# 2      integrin binding
# 3      integrin binding
# 4      integrin binding
# ..                  ...
# 624  calmodulin binding
# 625  calmodulin binding
# 626  calmodulin binding
# 627  calmodulin binding
# 628  calmodulin binding
#
# [629 rows x 4 columns]

# %%
mf_final.to_csv('mf.csv')

# %%
pthw_final = pthw[['Category', 'Term', 'Genes']].set_index(['Category', 'Term']).apply(lambda x: x.str.split(',').explode()).reset_index().dropna().drop_duplicates()
pthw_final['pthw'] = pthw_final['Term'].apply(lambda x: x.split(':')[1])
pthw_final
# Out:
#          Category                                            Term    Genes  \
# 0    KEGG_PATHWAY  hsa04923:Regulation of lipolysis in adipocytes    FABP4
# 1    KEGG_PATHWAY  hsa04923:Regulation of lipolysis in adipocytes     NPR1
# 2    KEGG_PATHWAY  hsa04923:Regulation of lipolysis in adipocytes   PTGER3
# 3    KEGG_PATHWAY  hsa04923:Regulation of lipolysis in adipocytes    ADCY4
# 4    KEGG_PATHWAY  hsa04923:Regulation of lipolysis in adipocytes    NPY1R
# ..            ...                                             ...      ...
# 353  KEGG_PATHWAY              hsa04926:Relaxin signaling pathway    ADCY4
# 354  KEGG_PATHWAY              hsa04926:Relaxin signaling pathway    ADCY3
# 355  KEGG_PATHWAY              hsa04926:Relaxin signaling pathway     KRAS
# 356  KEGG_PATHWAY              hsa04926:Relaxin signaling pathway     NOS1
# 357  KEGG_PATHWAY              hsa04926:Relaxin signaling pathway    GNG11
#
#                                       pthw
# 0    Regulation of lipolysis in adipocytes
# 1    Regulation of lipolysis in adipocytes
# 2    Regulation of lipolysis in adipocytes
# 3    Regulation of lipolysis in adipocytes
# 4    Regulation of lipolysis in adipocytes
# ..                                     ...
# 353              Relaxin signaling pathway
# 354              Relaxin signaling pathway
# 355              Relaxin signaling pathway
# 356              Relaxin signaling pathway
# 357              Relaxin signaling pathway
#
# [358 rows x 4 columns]

# %%
pthw_final.to_csv('pathway.csv')
