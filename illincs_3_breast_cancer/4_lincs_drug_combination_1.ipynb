# %%
import pandas as pd
import os
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt

# %% [markdown]
# # Read files for drug combiantion

# %%
# read the expression data from every file and combine them together
file_path = '/Users/yanlixu/Desktop/pingan/合作/CDK12/220616/LINSCP_for_drug_combinations'
files = os.listdir(file_path)

file_list = []
gene_list = []
diff_value_list = []

for file in files:
    if os.path.isfile(os.path.join(file_path, file)):
        file_list.append(file.replace(' .csv', ''))
        if file == 'LINCSCP_30171 .csv':
            gene_list = data['Name_GeneSymbol'].tolist()       
        data = pd.read_csv(os.path.join(file_path, file))
        diff_value_list.append(data['Value_LogDiffExp'].tolist())
        
diff_value_df = pd.DataFrame(diff_value_list)
diff_value_df = diff_value_df.transpose()

diff_value_df.columns = file_list
diff_value_df.index = gene_list
diff_value_df
# Out:
#          LINCSCP_38362  LINCSCP_34341  LINCSCP_143009  LINCSCP_32915  \
# AARS          1.494280      -0.619955        4.019460      -2.331810
# ABCF1        -1.079000       0.331871       -0.869827      -2.765140
# ABL1         -2.922490      -1.064530       -1.657750      -1.158990
# ACAA1         0.546718      -0.595667        1.216550      -0.091681
# ACAT2        -0.059628       0.649373       -2.380550       0.433265
# ...                ...            ...             ...            ...
# TXLNA         1.076610      -0.288040       -0.283192      -1.379400
# SPRED2        0.163661       0.161295       -0.167704       0.846945
# EML3          0.070458      -0.986843       -1.313710      -0.511510
# TMEM110      -1.040950       0.253314       -1.342180       0.459366
# FAM69A        0.027207       0.853779       -2.718890       0.410731
#
#          LINCSCP_30882  LINCSCP_32041  LINCSCP_30343  LINCSCP_134030  \
# AARS         -0.063457      -4.853260       0.635163       -2.613470
# ABCF1         0.153361       0.990553       0.436411       -0.115094
# ABL1         -0.280789      -1.238150       0.883352       -1.196040
# ACAA1         0.586592       0.293339      -0.100985       -0.687410
# ACAT2         0.409297      -2.025530       0.289256       -0.413886
# ...                ...            ...            ...             ...
# TXLNA         0.105837       0.584791      -0.095763        1.200010
# SPRED2        0.035816      -1.679320       0.583823        0.548437
# EML3          0.375487       1.721950       1.640430       -0.792332
# TMEM110       0.457051       4.215620      -0.798682       -0.460531
# FAM69A        0.507479      -1.213580      -0.274027        0.117494
#
#          LINCSCP_138013  LINCSCP_30986  ...  LINCSCP_38863  LINCSCP_37738  \
# AARS           -1.33500      -0.343550  ...       -0.64210       0.589441
# ABCF1           0.09200       0.867296  ...       -0.47790      -1.014340
# ABL1           -1.34635      -0.225222  ...       -4.68355      -0.174940
# ACAA1          -2.61995       0.108072  ...        3.88960       0.040737
# ACAT2           1.85050       0.904678  ...        1.39060      -0.500403
# ...                 ...            ...  ...            ...            ...
# TXLNA          -1.26715      -0.834586  ...       -4.34090      -0.122994
# SPRED2         -0.11865       0.395441  ...        0.98630      -0.669213
# EML3           -0.56980      -0.736650  ...        0.30320       0.213313
# TMEM110         0.42335      -0.845484  ...        0.73525      -0.888186
# FAM69A          0.83545      -0.192166  ...        0.78975      -0.800063
#
#          LINCSCP_138138  LINCSCP_140489  LINCSCP_241019  LINCSCP_32717  \
# AARS           2.275850        0.317485        0.299537      -0.053473
# ABCF1          1.184140        0.140167       -1.243110       0.307844
# ABL1           0.401152        0.459429       -0.699727       0.388227
# ACAA1          0.228642        0.735920        0.177715       0.295074
# ACAT2         -0.585729        1.071690       -0.099666      -0.434428
# ...                 ...             ...             ...            ...
# TXLNA         -0.684713        0.279481       -0.720292       1.063460
# SPRED2        -2.169700        0.808282       -0.118622       0.275208
# EML3           0.105797        0.037861       -0.675822       0.762196
# TMEM110       -0.288151        0.236437        0.045929      -0.023631
# FAM69A         0.012822        0.910366        0.427058      -0.349044
#
#          LINCSCP_138883  LINCSCP_37329  LINCSCP_141670  LINCSCP_240171
# AARS          -8.767110       0.926990       -1.721910       -1.147110
# ABCF1          2.176350       0.208830        0.017453        0.499426
# ABL1          -1.595640      -3.406730        0.017226       -1.449620
# ACAA1          3.775060      -0.225089        0.730956        0.130912
# ACAT2          0.624442      -5.543650        0.607123       -0.082746
# ...                 ...            ...             ...             ...
# TXLNA          5.526860      -0.075133       -0.397316        0.573336
# SPRED2         3.228020      -0.687351        0.855661        0.731780
# EML3           2.179590       0.117983        0.021021        0.377983
# TMEM110        3.798570       2.154920        0.379698        0.597835
# FAM69A         4.756390      -1.160400        1.453300        0.605177
#
# [978 rows x 429 columns]

# %%
diff_value_df.columns
# Out:
# Index(['LINCSCP_38362', 'LINCSCP_34341', 'LINCSCP_143009', 'LINCSCP_32915',
#        'LINCSCP_30882', 'LINCSCP_32041', 'LINCSCP_30343', 'LINCSCP_134030',
#        'LINCSCP_138013', 'LINCSCP_30986',
#        ...
#        'LINCSCP_38863', 'LINCSCP_37738', 'LINCSCP_138138', 'LINCSCP_140489',
#        'LINCSCP_241019', 'LINCSCP_32717', 'LINCSCP_138883', 'LINCSCP_37329',
#        'LINCSCP_141670', 'LINCSCP_240171'],
#       dtype='object', length=429)

# %% [markdown]
# # only compare the intersection genes of *top up/down regulated genes from disease* and *978 genes from purturbanges*

# %%
# read top up and down regulated genes data
top_genes_data = pd.read_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220616/1_breast_cancer_20220616.xlsx', sheet_name='top_843_genes')

top_genes_data = top_genes_data.set_index('Name_GeneSymbol')
top_genes_data
# Out:
#                            PROBE  ID_geneid  \
# Name_GeneSymbol
# LRRC3B           ENSG00000179796     116135
# EDN3             ENSG00000124205       1908
# SLC7A3           ENSG00000165349      84889
# RNF186           ENSG00000178828      54546
# NPY5R            ENSG00000164129       4889
# ...                          ...        ...
# ATP1A2           ENSG00000018625        477
# SPAG5            ENSG00000076382      10615
# FGD6             ENSG00000180263      55785
# BARD1            ENSG00000138376        580
# RELN             ENSG00000189056       5649
#
#                                                        Description  \
# Name_GeneSymbol
# LRRC3B                           leucine rich repeat containing 3B
# EDN3                                                  endothelin 3
# SLC7A3           solute carrier family 7 (cationic amino acid t...
# RNF186                                     ring finger protein 186
# NPY5R                                   neuropeptide Y receptor Y5
# ...                                                            ...
# ATP1A2            ATPase, Na+/K+ transporting, alpha 2 polypeptide
# SPAG5                                   sperm associated antigen 5
# FGD6                       FYVE, RhoGEF and PH domain containing 6
# BARD1                               BRCA1 associated RING domain 1
# RELN                                                        reelin
#
#                  HER2-enriched  Normal-like  Value_LogDiffExp  \
# Name_GeneSymbol
# LRRC3B                0.479733     3.371910          2.892178
# EDN3                  0.833259     7.154483          6.321224
# SLC7A3                0.782743     4.942493          4.159750
# RNF186                0.435500     3.645805          3.210305
# NPY5R                 0.576462     3.933840          3.357378
# ...                        ...          ...               ...
# ATP1A2                3.340342     5.759227          2.418885
# SPAG5                10.149744     8.770578         -1.379166
# FGD6                  9.496706     8.556814         -0.939892
# BARD1                 7.205341     5.877754         -1.327586
# RELN                  3.818393     6.266277          2.447883
#
#                  Significance_pvalue
# Name_GeneSymbol
# LRRC3B                  2.048665e-18
# EDN3                    1.209711e-15
# SLC7A3                  8.288257e-15
# RNF186                  3.533317e-14
# NPY5R                   1.756614e-13
# ...                              ...
# ATP1A2                  4.934741e-04
# SPAG5                   4.951546e-04
# FGD6                    4.954145e-04
# BARD1                   4.969373e-04
# RELN                    4.986528e-04
#
# [853 rows x 7 columns]

# %%
# merge two dataframe
df_merged = pd.merge(diff_value_df, top_genes_data[['Value_LogDiffExp']], left_index=True, right_index=True)
df_merged.rename(columns={'Value_LogDiffExp': 'breast_cancer_reverse_gene_expression'}, inplace=True)
df_merged
# Out:
#          LINCSCP_38362  LINCSCP_34341  LINCSCP_143009  LINCSCP_32915  \
# ADCK3         3.344650      -0.480999       -0.895200      -0.855684
# BUB1B        -0.535794       1.055980       -0.901259       0.800071
# CCNE2        -2.818080      -0.164087       -2.393930       0.365751
# CDC45        -2.254000      -0.837349       -1.275280      -2.951870
# CEBPD         3.900860       1.184460        0.563898       1.282320
# CXCL2         1.360430      -0.241379        1.175050      -0.785206
# DNMT3A        0.148841       1.090890        0.822662       0.601614
# EML3          0.070458      -0.986843       -1.313710      -0.511510
# ERBB2        -1.605100      -1.891180       -1.117130      -5.133450
# FGFR4         0.158094      -0.338320       -1.122110      -0.215939
# GADD45B      -0.084127      -0.109147        1.660560      -0.005756
# GNA15        -0.015363       0.754299        0.255567       2.812510
# GRB7         -0.193999      -1.367820       -0.068185       0.468212
# GSTM2         0.698340      -0.010417        0.818525       0.927115
# HDAC2        -0.636867      -1.044870        0.703528       2.956210
# HMGCR         0.934422      -0.189031       -1.115990       0.211559
# HOXA5         0.243034       0.226899        2.588840      -0.331145
# HSPA8        -1.483600      -0.828392       -4.466820      -0.608944
# IDE          -0.006740      -0.481520       -0.244320      -0.396815
# INPP1        -0.655998      -0.242144        0.298196       0.278205
# KDM5B         0.247977      -0.304980        0.736301      -1.288070
# KIF14         0.038464       0.207851       -4.805420      -0.138795
# KIF20A        1.493510      -1.121580       -2.054590       0.256268
# KIT          -0.137399      -0.380553        0.481332       3.469160
# KLHL21        0.180120      -0.980266       -0.954841      -0.340586
# LAMA3         1.459710      -0.257526        0.550837      -0.549856
# MYO10        -0.116494       0.274079       -0.457620      -1.126930
# PDGFA         2.095680       0.171962        0.146589       0.231468
# PPP2R5E      -0.492412       0.143011        1.156990      -0.979880
# PROS1         0.635893      -0.080992        0.482071       0.017297
# PTGS2        -1.127900       2.710710       -0.350018      -0.271286
# PTPN6         0.791143       0.466687       -0.077094      -0.365828
# SMARCC1       0.212139       0.949550        0.862189      -2.002480
# SNCA          0.752974       0.839605        0.166914       1.484050
# SORBS3        0.765010      -0.210530       -0.406989      -1.713090
# TUBB6         0.498450       0.646409       -3.110720       0.128376
# ZFP36         1.219680       0.139850        2.468640      -0.740363
#
#          LINCSCP_30882  LINCSCP_32041  LINCSCP_30343  LINCSCP_134030  \
# ADCK3         1.242360       3.029420      -0.473526       -0.071473
# BUB1B         0.924479      -1.014300       1.024760       -0.117735
# CCNE2        -0.983786       2.177360      -0.680540       -0.252691
# CDC45        -1.685080      -5.170150      -0.672461       -0.706304
# CEBPD         0.933635       2.758190       0.508466       -0.604806
# CXCL2         0.711055       3.983530       1.632660        3.352420
# DNMT3A       -0.333703       1.328110       0.725167       -0.276221
# EML3          0.375487       1.721950       1.640430       -0.792332
# ERBB2        -1.423450      -0.263740      -1.839590       -1.121880
# FGFR4         0.033537       1.050760       0.835038       -1.036270
# GADD45B      -0.291109      -0.571547      -0.302810        0.411597
# GNA15         0.339681      -0.287822       0.371448        0.436790
# GRB7          0.484888      -0.136909       0.314966        0.133696
# GSTM2         1.273260       1.332800       0.401581        0.053992
# HDAC2        -0.225790      -1.272270      -0.747511       -0.407623
# HMGCR         0.747429       0.577883       0.420578       -0.606378
# HOXA5         0.467237       0.533139       0.797218        0.562085
# HSPA8         0.224728      -2.298600      -0.587263       -0.668012
# IDE          -1.086960       1.621340      -0.432731       -0.891269
# INPP1         0.454122       2.914670       0.485296        0.853375
# KDM5B        -0.571209      -2.791400       1.065210        1.398450
# KIF14        -1.333330      -6.518820      -0.585335       -3.096290
# KIF20A       -0.101459      -4.427990       0.091254       -3.251230
# KIT           0.066332       0.324077       1.510540       -0.129807
# KLHL21       -0.462288       4.313340      -0.003445       -0.401034
# LAMA3        -0.473519       4.629810       0.146468        0.602317
# MYO10        -0.655550       2.023160       0.266844       -0.053440
# PDGFA        -0.945444      -1.943160      -0.080364       -0.451834
# PPP2R5E       0.416217      -4.952300      -1.378420       -0.126962
# PROS1         0.555500       1.702190      -0.115724        1.253290
# PTGS2         0.818083       3.041240       0.289497        0.238413
# PTPN6         0.040320       2.009460      -0.107124        1.514940
# SMARCC1      -0.701780       0.409551       0.994440       -0.368860
# SNCA          0.351302       0.082307       0.638541       -0.473642
# SORBS3        0.082128       3.105100      -0.141506       -1.733820
# TUBB6        -0.294228      -5.097840       0.644996       -2.230760
# ZFP36         0.795138       1.196820       1.511030        0.020829
#
#          LINCSCP_138013  LINCSCP_30986  ...  LINCSCP_37738  LINCSCP_138138  \
# ADCK3          -0.43335      -1.545280  ...       0.283524        0.039594
# BUB1B          -0.08335       0.651494  ...      -0.721430        0.679856
# CCNE2          -0.39125       0.340207  ...      -0.144835        0.527185
# CDC45           0.85595      -2.320670  ...      -0.370275        0.123617
# CEBPD           0.06315       0.374499  ...      -0.951428        1.761570
# CXCL2           5.11535       2.341350  ...       1.057060        3.786880
# DNMT3A          0.23445       0.308116  ...      -0.613750        0.433469
# EML3           -0.56980      -0.736650  ...       0.213313        0.105797
# ERBB2          -0.39840      -0.880392  ...      -0.115905        0.628674
# FGFR4          -0.67540      -0.445151  ...      -0.558800       -0.335751
# GADD45B        -0.23180      -0.959357  ...      -0.422955        1.201670
# GNA15           4.78785       1.048830  ...       0.152454        0.430054
# GRB7           -0.01385       0.334257  ...      -1.519590        0.250404
# GSTM2           0.30555       0.858932  ...      -0.141981        1.504080
# HDAC2           0.98575      -0.182471  ...       0.331042       -0.864260
# HMGCR          -0.15930       0.926927  ...       0.257033       -0.543589
# HOXA5           1.59275       0.223192  ...      -0.172176        0.515980
# HSPA8          -0.63890      -0.640501  ...       0.525854       -1.096510
# IDE             0.07095       0.041859  ...      -0.185977       -0.839930
# INPP1           0.14310       0.226590  ...      -0.761948        0.412321
# KDM5B          -1.01035      -0.699959  ...      -0.042410       -0.338095
# KIF14          -0.11720      -1.680940  ...      -0.712575       -0.620669
# KIF20A         -0.20355      -0.012478  ...       0.332457       -1.535560
# KIT             0.99595       0.306818  ...       0.162612        0.365187
# KLHL21         -0.53450       1.312200  ...       0.983127       -0.543792
# LAMA3          -0.14105       1.297850  ...       0.717905        0.924703
# MYO10          -0.23675       0.005609  ...      -0.645371        0.296409
# PDGFA           0.52395       0.023119  ...       0.594370        0.433193
# PPP2R5E        -0.10325       0.627673  ...      -0.044570        0.779325
# PROS1          -0.77095       0.085106  ...      -0.207772       -0.398860
# PTGS2           4.65520       1.799850  ...       0.500716        3.194290
# PTPN6          -0.10560      -0.108355  ...       0.703489        0.680331
# SMARCC1        -0.47220      -0.569039  ...      -0.444047        1.006390
# SNCA            0.20900       0.317064  ...      -0.693655        1.165860
# SORBS3         -0.51335      -0.245188  ...       0.167523       -0.010291
# TUBB6           0.26700      -0.541280  ...      -0.146376       -2.028370
# ZFP36          -1.67395       0.601633  ...       0.189694       -0.387670
#
#          LINCSCP_140489  LINCSCP_241019  LINCSCP_32717  LINCSCP_138883  \
# ADCK3         -0.731677       -0.656532       0.270918        5.819600
# BUB1B          0.985430        0.447037      -0.389038        2.908880
# CCNE2         -2.343720       -0.320007       0.409466       -0.372127
# CDC45         -1.020580        0.446797       0.347484       -2.979670
# CEBPD          1.086420        2.241140       0.392258        3.817730
# CXCL2          3.344020       -0.002685      -0.402729       -1.459990
# DNMT3A        -2.688960        0.470856      -0.038314        3.468930
# EML3           0.037861       -0.675822       0.762196        2.179590
# ERBB2         -0.356517       -4.634300      -1.919790       -2.770220
# FGFR4          0.520163        0.625977      -0.206554        1.987380
# GADD45B        0.222978       -0.384980       0.398811       10.000000
# GNA15         -0.451191        0.452200      -0.222216        1.887830
# GRB7           0.200374        0.131264       0.021008        3.732110
# GSTM2         -0.134017       -1.094610      -0.007112        3.149660
# HDAC2         -0.465490        0.196189       0.025133       -7.257920
# HMGCR          0.830469        0.468475      -0.772733        1.996140
# HOXA5         -0.648742        1.534290       0.426062        6.336430
# HSPA8         -0.868298       -1.167830       0.720037       -6.746880
# IDE            0.161798        0.312003      -0.187371        1.617230
# INPP1          0.970333        0.299516       0.949169       10.000000
# KDM5B          0.383587       -0.701481      -0.551520        0.776751
# KIF14         -0.560182       -1.974200      -0.793501       -5.170320
# KIF20A         0.289486       -0.458427      -1.489070       -7.262060
# KIT            0.537342        0.388853       0.737696        6.051000
# KLHL21        -0.895170        0.139277       0.575206       10.000000
# LAMA3          0.942944        0.713226       0.848025       -0.756074
# MYO10          0.090669        1.236740       0.087105        2.430880
# PDGFA          0.267154        0.164709       0.131775        7.246200
# PPP2R5E       -0.824631       -3.110510      -0.527411       -3.639290
# PROS1          0.257418        0.134824       0.272696        0.672375
# PTGS2          1.845850        0.247623      -0.103894        4.066210
# PTPN6         -0.128884       -0.340460       0.044690       -1.864780
# SMARCC1       -0.456744        0.292702      -0.230447       -5.938610
# SNCA           0.252396        1.968970       0.233744        3.501200
# SORBS3         1.617530       -0.476121       0.065587       -2.481200
# TUBB6          0.526639       -1.719710       0.576731        3.101840
# ZFP36          0.727976       -0.555992      -0.424532        6.751040
#
#          LINCSCP_37329  LINCSCP_141670  LINCSCP_240171  \
# ADCK3         3.669820       -1.614830        1.013950
# BUB1B        -0.267041        0.416413        0.406441
# CCNE2        -4.664130       -3.743570       -1.042460
# CDC45        -0.268966        0.591969        0.457534
# CEBPD         3.270850        2.734010        2.605530
# CXCL2         6.742710        2.711570        1.452370
# DNMT3A        0.985208        0.049158        1.047390
# EML3          0.117983        0.021021        0.377983
# ERBB2        -3.343500       -0.908589       -2.882390
# FGFR4        -1.664230       -0.742038        0.266055
# GADD45B      -2.714220       -0.636912       -1.545710
# GNA15         1.438130        0.954794        2.295290
# GRB7          0.195469        0.127431       -0.683005
# GSTM2         1.162360       -0.697607        0.316718
# HDAC2         0.635775       -0.899764       -0.314760
# HMGCR        -1.352460       -0.695803       -0.198648
# HOXA5         2.022370        0.104991       -0.068325
# HSPA8         2.016710       -4.835660        0.318245
# IDE          -0.379731       -2.138900       -0.231694
# INPP1         6.058900        0.615512       -0.676593
# KDM5B        -0.513627       -1.176600       -0.464554
# KIF14        -0.092952        0.594885       -2.045830
# KIF20A        1.065300       -0.762823       -4.327030
# KIT           4.512550        0.150602        0.502337
# KLHL21        2.892990       -0.839235        0.321190
# LAMA3        -0.438640       -0.453342        1.166600
# MYO10         2.675200       -0.960615        0.951463
# PDGFA        -1.976430       -0.372961        0.104682
# PPP2R5E      -2.540150        0.055600       -0.563404
# PROS1         5.930220        0.125136       -0.179115
# PTGS2         3.064910        1.371040        0.008011
# PTPN6         2.591500       -0.771207        0.374796
# SMARCC1       1.095000        1.327170       -0.501617
# SNCA         -3.952460        0.252273        0.078405
# SORBS3        0.023372       -0.159052       -1.354910
# TUBB6        -0.856333       -0.115145       -1.250930
# ZFP36        -0.768014        1.821870       -0.333077
#
#          breast_cancer_reverse_gene_expression
# ADCK3                                 1.028460
# BUB1B                                -1.088888
# CCNE2                                -1.342595
# CDC45                                -1.235306
# CEBPD                                 1.654624
# CXCL2                                 3.079541
# DNMT3A                               -0.889459
# EML3                                  0.665903
# ERBB2                                -3.667586
# FGFR4                                -2.551568
# GADD45B                               0.963738
# GNA15                                 1.980505
# GRB7                                 -3.044634
# GSTM2                                 2.436872
# HDAC2                                -0.855360
# HMGCR                                -0.960448
# HOXA5                                 1.961729
# HSPA8                                -0.978438
# IDE                                  -1.065555
# INPP1                                 1.092768
# KDM5B                                -1.119670
# KIF14                                -1.427973
# KIF20A                               -1.086525
# KIT                                   2.614903
# KLHL21                                1.070629
# LAMA3                                 2.494518
# MYO10                                -1.271074
# PDGFA                                 1.128307
# PPP2R5E                              -0.663479
# PROS1                                 1.349912
# PTGS2                                 2.527868
# PTPN6                                 0.731777
# SMARCC1                              -0.735897
# SNCA                                  1.377548
# SORBS3                                1.199422
# TUBB6                                 1.021984
# ZFP36                                 1.514885
#
# [37 rows x 430 columns]

# %% [markdown]
# # Calculation 1: compounds compare with 'LINCSCP_33167'

# %%
# if the expression value same direction (both upregulated or both down regulated) with LINCSCP_33167, then 1; else 0
def compare(col1, col2):
    result = col1 * col2
    return [1 if res > 0 else 0 for res in result] 

df_merged_1 = df_merged.drop(columns=['breast_cancer_reverse_gene_expression'])
result_1 = []
for col in df_merged_1.columns.tolist():
    result_1.append(compare(df_merged_1['LINCSCP_33167'], df_merged_1[col]))
result_1_df = pd.DataFrame(result_1, columns = df_merged_1.index.tolist())
result_1_df.index = df_merged_1.columns
result_1_df
# Out:
#                 ADCK3  BUB1B  CCNE2  CDC45  CEBPD  CXCL2  DNMT3A  EML3  ERBB2  \
# LINCSCP_38362       1      0      1      0      1      1       1     0      1
# LINCSCP_34341       0      1      1      0      1      0       1     1      1
# LINCSCP_143009      0      0      1      0      1      1       1     1      1
# LINCSCP_32915       0      1      0      0      1      0       1     1      1
# LINCSCP_30882       1      1      1      0      1      1       0     0      1
# ...               ...    ...    ...    ...    ...    ...     ...   ...    ...
# LINCSCP_32717       1      0      0      1      1      0       0     0      1
# LINCSCP_138883      1      1      1      0      1      0       1     0      1
# LINCSCP_37329       1      0      1      0      1      1       1     0      1
# LINCSCP_141670      0      1      1      1      1      1       1     0      1
# LINCSCP_240171      1      1      1      1      1      1       1     0      1
#
#                 FGFR4  ...  PDGFA  PPP2R5E  PROS1  PTGS2  PTPN6  SMARCC1  \
# LINCSCP_38362       1  ...      0        1      0      0      1        0
# LINCSCP_34341       0  ...      0        0      1      1      1        0
# LINCSCP_143009      0  ...      0        0      0      0      0        0
# LINCSCP_32915       0  ...      0        1      0      0      0        1
# LINCSCP_30882       1  ...      1        0      0      1      1        1
# ...               ...  ...    ...      ...    ...    ...    ...      ...
# LINCSCP_32717       0  ...      0        1      0      0      1        1
# LINCSCP_138883      1  ...      0        1      0      1      0        1
# LINCSCP_37329       0  ...      1        1      0      1      1        0
# LINCSCP_141670      0  ...      1        0      0      1      0        0
# LINCSCP_240171      1  ...      0        1      1      1      1        1
#
#                 SNCA  SORBS3  TUBB6  ZFP36
# LINCSCP_38362      1       0      1      1
# LINCSCP_34341      1       1      1      1
# LINCSCP_143009     1       1      0      1
# LINCSCP_32915      1       1      1      0
# LINCSCP_30882      1       0      0      1
# ...              ...     ...    ...    ...
# LINCSCP_32717      1       0      1      0
# LINCSCP_138883     1       1      1      1
# LINCSCP_37329      0       0      0      0
# LINCSCP_141670     1       1      0      1
# LINCSCP_240171     1       1      0      0
#
# [429 rows x 37 columns]

# %%
ax = sns.clustermap(result_1_df, standard_scale=1, cmap="vlag")
plt.show()
# Out:
# /opt/anaconda3/envs/deepchem_py37/lib/python3.7/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
result_1_df['sum_of_same_dir_genes'] = result_1_df.sum(axis=1)
result_1_df
# Out:
#                 ADCK3  BUB1B  CCNE2  CDC45  CEBPD  CXCL2  DNMT3A  EML3  ERBB2  \
# LINCSCP_38362       1      0      1      0      1      1       1     0      1
# LINCSCP_34341       0      1      1      0      1      0       1     1      1
# LINCSCP_143009      0      0      1      0      1      1       1     1      1
# LINCSCP_32915       0      1      0      0      1      0       1     1      1
# LINCSCP_30882       1      1      1      0      1      1       0     0      1
# ...               ...    ...    ...    ...    ...    ...     ...   ...    ...
# LINCSCP_32717       1      0      0      1      1      0       0     0      1
# LINCSCP_138883      1      1      1      0      1      0       1     0      1
# LINCSCP_37329       1      0      1      0      1      1       1     0      1
# LINCSCP_141670      0      1      1      1      1      1       1     0      1
# LINCSCP_240171      1      1      1      1      1      1       1     0      1
#
#                 FGFR4  ...  PPP2R5E  PROS1  PTGS2  PTPN6  SMARCC1  SNCA  \
# LINCSCP_38362       1  ...        1      0      0      1        0     1
# LINCSCP_34341       0  ...        0      1      1      1        0     1
# LINCSCP_143009      0  ...        0      0      0      0        0     1
# LINCSCP_32915       0  ...        1      0      0      0        1     1
# LINCSCP_30882       1  ...        0      0      1      1        1     1
# ...               ...  ...      ...    ...    ...    ...      ...   ...
# LINCSCP_32717       0  ...        1      0      0      1        1     1
# LINCSCP_138883      1  ...        1      0      1      0        1     1
# LINCSCP_37329       0  ...        1      0      1      1        0     0
# LINCSCP_141670      0  ...        0      0      1      0        0     1
# LINCSCP_240171      1  ...        1      1      1      1        1     1
#
#                 SORBS3  TUBB6  ZFP36  sum_of_same_dir_genes
# LINCSCP_38362        0      1      1                     18
# LINCSCP_34341        1      1      1                     23
# LINCSCP_143009       1      0      1                     20
# LINCSCP_32915        1      1      0                     22
# LINCSCP_30882        0      0      1                     27
# ...                ...    ...    ...                    ...
# LINCSCP_32717        0      1      0                     19
# LINCSCP_138883       1      1      1                     28
# LINCSCP_37329        0      0      0                     21
# LINCSCP_141670       1      0      1                     24
# LINCSCP_240171       1      0      0                     25
#
# [429 rows x 38 columns]

# %%
result_1_df['sum_of_same_dir_genes_rate'] = round(result_1_df['sum_of_same_dir_genes']/37, 2)
result_1_df
# Out:
#                 ADCK3  BUB1B  CCNE2  CDC45  CEBPD  CXCL2  DNMT3A  EML3  ERBB2  \
# LINCSCP_38362       1      0      1      0      1      1       1     0      1
# LINCSCP_34341       0      1      1      0      1      0       1     1      1
# LINCSCP_143009      0      0      1      0      1      1       1     1      1
# LINCSCP_32915       0      1      0      0      1      0       1     1      1
# LINCSCP_30882       1      1      1      0      1      1       0     0      1
# ...               ...    ...    ...    ...    ...    ...     ...   ...    ...
# LINCSCP_32717       1      0      0      1      1      0       0     0      1
# LINCSCP_138883      1      1      1      0      1      0       1     0      1
# LINCSCP_37329       1      0      1      0      1      1       1     0      1
# LINCSCP_141670      0      1      1      1      1      1       1     0      1
# LINCSCP_240171      1      1      1      1      1      1       1     0      1
#
#                 FGFR4  ...  PROS1  PTGS2  PTPN6  SMARCC1  SNCA  SORBS3  TUBB6  \
# LINCSCP_38362       1  ...      0      0      1        0     1       0      1
# LINCSCP_34341       0  ...      1      1      1        0     1       1      1
# LINCSCP_143009      0  ...      0      0      0        0     1       1      0
# LINCSCP_32915       0  ...      0      0      0        1     1       1      1
# LINCSCP_30882       1  ...      0      1      1        1     1       0      0
# ...               ...  ...    ...    ...    ...      ...   ...     ...    ...
# LINCSCP_32717       0  ...      0      0      1        1     1       0      1
# LINCSCP_138883      1  ...      0      1      0        1     1       1      1
# LINCSCP_37329       0  ...      0      1      1        0     0       0      0
# LINCSCP_141670      0  ...      0      1      0        0     1       1      0
# LINCSCP_240171      1  ...      1      1      1        1     1       1      0
#
#                 ZFP36  sum_of_same_dir_genes  sum_of_same_dir_genes_rate
# LINCSCP_38362       1                     18                        0.49
# LINCSCP_34341       1                     23                        0.62
# LINCSCP_143009      1                     20                        0.54
# LINCSCP_32915       0                     22                        0.59
# LINCSCP_30882       1                     27                        0.73
# ...               ...                    ...                         ...
# LINCSCP_32717       0                     19                        0.51
# LINCSCP_138883      1                     28                        0.76
# LINCSCP_37329       0                     21                        0.57
# LINCSCP_141670      1                     24                        0.65
# LINCSCP_240171      0                     25                        0.68
#
# [429 rows x 39 columns]

# %%
result_1_df.to_csv('test1.csv')

# %% [markdown]
# # Calculation 2: compounds compare with reverse_of_breast_cancer

# %%
# if the expression value same direction (both upregulated or both down regulated) with reverse_of_breast_cancer, then 1; else 0


def compare(col1, col2):
    result = col1 * col2
    return [1 if res > 0 else 0 for res in result] 

#df_merged_1 = df_merged.drop(columns=['breast_cancer_reverse_gene_expression'])
result_2 = []
for col in df_merged.columns.tolist():
    result_2.append(compare(df_merged['breast_cancer_reverse_gene_expression'], df_merged[col]))
result_2_df = pd.DataFrame(result_2, columns = df_merged.index.tolist())
result_2_df.index = df_merged.columns
result_2_df
# Out:
#                                        ADCK3  BUB1B  CCNE2  CDC45  CEBPD  \
# LINCSCP_38362                              1      1      1      1      1
# LINCSCP_34341                              0      0      1      1      1
# LINCSCP_143009                             0      1      1      1      1
# LINCSCP_32915                              0      0      0      1      1
# LINCSCP_30882                              1      0      1      1      1
# ...                                      ...    ...    ...    ...    ...
# LINCSCP_138883                             1      0      1      1      1
# LINCSCP_37329                              1      1      1      1      1
# LINCSCP_141670                             0      0      1      0      1
# LINCSCP_240171                             1      0      1      0      1
# breast_cancer_reverse_gene_expression      1      1      1      1      1
#
#                                        CXCL2  DNMT3A  EML3  ERBB2  FGFR4  ...  \
# LINCSCP_38362                              1       0     1      1      0  ...
# LINCSCP_34341                              0       0     0      1      1  ...
# LINCSCP_143009                             1       0     0      1      1  ...
# LINCSCP_32915                              0       0     0      1      1  ...
# LINCSCP_30882                              1       1     1      1      0  ...
# ...                                      ...     ...   ...    ...    ...  ...
# LINCSCP_138883                             0       0     1      1      0  ...
# LINCSCP_37329                              1       0     1      1      1  ...
# LINCSCP_141670                             1       0     1      1      1  ...
# LINCSCP_240171                             1       0     1      1      0  ...
# breast_cancer_reverse_gene_expression      1       1     1      1      1  ...
#
#                                        PDGFA  PPP2R5E  PROS1  PTGS2  PTPN6  \
# LINCSCP_38362                              1        1      1      0      1
# LINCSCP_34341                              1        0      0      1      1
# LINCSCP_143009                             1        0      1      0      0
# LINCSCP_32915                              1        1      1      0      0
# LINCSCP_30882                              0        0      1      1      1
# ...                                      ...      ...    ...    ...    ...
# LINCSCP_138883                             1        1      1      1      0
# LINCSCP_37329                              0        1      1      1      1
# LINCSCP_141670                             0        0      1      1      0
# LINCSCP_240171                             1        1      0      1      1
# breast_cancer_reverse_gene_expression      1        1      1      1      1
#
#                                        SMARCC1  SNCA  SORBS3  TUBB6  ZFP36
# LINCSCP_38362                                0     1       1      1      1
# LINCSCP_34341                                0     1       0      1      1
# LINCSCP_143009                               0     1       0      0      1
# LINCSCP_32915                                1     1       0      1      0
# LINCSCP_30882                                1     1       1      0      1
# ...                                        ...   ...     ...    ...    ...
# LINCSCP_138883                               1     1       0      1      1
# LINCSCP_37329                                0     0       1      0      0
# LINCSCP_141670                               0     1       0      0      1
# LINCSCP_240171                               1     1       0      0      0
# breast_cancer_reverse_gene_expression        1     1       1      1      1
#
# [430 rows x 37 columns]

# %%
ax = sns.clustermap(result_2_df, standard_scale=1, cmap="vlag")
plt.show()
# Out:
# /opt/anaconda3/envs/deepchem_py37/lib/python3.7/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# how many same direction with reverse_of_breast_cancer

result_2_df['sum_of_same_dir_genes'] = result_2_df.sum(axis=1)
result_2_df['sum_of_same_dir_genes_rate'] = round(result_2_df['sum_of_same_dir_genes']/37, 2)
result_2_df
# Out:
#                                        ADCK3  BUB1B  CCNE2  CDC45  CEBPD  \
# LINCSCP_38362                              1      1      1      1      1
# LINCSCP_34341                              0      0      1      1      1
# LINCSCP_143009                             0      1      1      1      1
# LINCSCP_32915                              0      0      0      1      1
# LINCSCP_30882                              1      0      1      1      1
# ...                                      ...    ...    ...    ...    ...
# LINCSCP_138883                             1      0      1      1      1
# LINCSCP_37329                              1      1      1      1      1
# LINCSCP_141670                             0      0      1      0      1
# LINCSCP_240171                             1      0      1      0      1
# breast_cancer_reverse_gene_expression      1      1      1      1      1
#
#                                        CXCL2  DNMT3A  EML3  ERBB2  FGFR4  ...  \
# LINCSCP_38362                              1       0     1      1      0  ...
# LINCSCP_34341                              0       0     0      1      1  ...
# LINCSCP_143009                             1       0     0      1      1  ...
# LINCSCP_32915                              0       0     0      1      1  ...
# LINCSCP_30882                              1       1     1      1      0  ...
# ...                                      ...     ...   ...    ...    ...  ...
# LINCSCP_138883                             0       0     1      1      0  ...
# LINCSCP_37329                              1       0     1      1      1  ...
# LINCSCP_141670                             1       0     1      1      1  ...
# LINCSCP_240171                             1       0     1      1      0  ...
# breast_cancer_reverse_gene_expression      1       1     1      1      1  ...
#
#                                        PROS1  PTGS2  PTPN6  SMARCC1  SNCA  \
# LINCSCP_38362                              1      0      1        0     1
# LINCSCP_34341                              0      1      1        0     1
# LINCSCP_143009                             1      0      0        0     1
# LINCSCP_32915                              1      0      0        1     1
# LINCSCP_30882                              1      1      1        1     1
# ...                                      ...    ...    ...      ...   ...
# LINCSCP_138883                             1      1      0        1     1
# LINCSCP_37329                              1      1      1        0     0
# LINCSCP_141670                             1      1      0        0     1
# LINCSCP_240171                             0      1      1        1     1
# breast_cancer_reverse_gene_expression      1      1      1        1     1
#
#                                        SORBS3  TUBB6  ZFP36  \
# LINCSCP_38362                               1      1      1
# LINCSCP_34341                               0      1      1
# LINCSCP_143009                              0      0      1
# LINCSCP_32915                               0      1      0
# LINCSCP_30882                               1      0      1
# ...                                       ...    ...    ...
# LINCSCP_138883                              0      1      1
# LINCSCP_37329                               1      0      0
# LINCSCP_141670                              0      0      1
# LINCSCP_240171                              0      0      0
# breast_cancer_reverse_gene_expression       1      1      1
#
#                                        sum_of_same_dir_genes  \
# LINCSCP_38362                                             25
# LINCSCP_34341                                             20
# LINCSCP_143009                                            25
# LINCSCP_32915                                             19
# LINCSCP_30882                                             26
# ...                                                      ...
# LINCSCP_138883                                            25
# LINCSCP_37329                                             24
# LINCSCP_141670                                            21
# LINCSCP_240171                                            24
# breast_cancer_reverse_gene_expression                     37
#
#                                        sum_of_same_dir_genes_rate
# LINCSCP_38362                                                0.68
# LINCSCP_34341                                                0.54
# LINCSCP_143009                                               0.68
# LINCSCP_32915                                                0.51
# LINCSCP_30882                                                0.70
# ...                                                           ...
# LINCSCP_138883                                               0.68
# LINCSCP_37329                                                0.65
# LINCSCP_141670                                               0.57
# LINCSCP_240171                                               0.65
# breast_cancer_reverse_gene_expression                        1.00
#
# [430 rows x 39 columns]

# %% [markdown]
# # merge two dataframe

# %%
df_final = pd.merge(result_1_df[['sum_of_same_dir_genes_rate']], result_2_df[['sum_of_same_dir_genes_rate']], left_index=True, right_index=True)
df_final.rename(columns={'sum_of_same_dir_genes_rate_x': 'percentage_of_same_direction_genes_w_33167', 'sum_of_same_dir_genes_rate_y': 'percentage_of_reverse_direction_genes_w_breast_cancer'}, inplace=True)

df_final['rank_score'] = round(df_final['percentage_of_reverse_direction_genes_w_breast_cancer']/df_final['percentage_of_same_direction_genes_w_33167'], 2)

# %%
df_final = df_final.sort_values(by=['rank_score'], ascending=False)
df_final
# Out:
#                 percentage_of_same_direction_genes_w_33167  \
# LINCSCP_34265                                         0.24
# LINCSCP_140577                                        0.30
# LINCSCP_132948                                        0.30
# LINCSCP_34739                                         0.32
# LINCSCP_137401                                        0.35
# ...                                                    ...
# LINCSCP_31216                                         0.78
# LINCSCP_133897                                        0.73
# LINCSCP_33167                                         1.00
# LINCSCP_35120                                         0.84
# LINCSCP_240981                                        0.73
#
#                 percentage_of_reverse_direction_genes_w_breast_cancer  \
# LINCSCP_34265                                                0.54
# LINCSCP_140577                                               0.59
# LINCSCP_132948                                               0.59
# LINCSCP_34739                                                0.62
# LINCSCP_137401                                               0.65
# ...                                                           ...
# LINCSCP_31216                                                0.54
# LINCSCP_133897                                               0.49
# LINCSCP_33167                                                0.65
# LINCSCP_35120                                                0.54
# LINCSCP_240981                                               0.43
#
#                 rank_score
# LINCSCP_34265         2.25
# LINCSCP_140577        1.97
# LINCSCP_132948        1.97
# LINCSCP_34739         1.94
# LINCSCP_137401        1.86
# ...                    ...
# LINCSCP_31216         0.69
# LINCSCP_133897        0.67
# LINCSCP_33167         0.65
# LINCSCP_35120         0.64
# LINCSCP_240981        0.59
#
# [429 rows x 3 columns]

# %%
# get chemical info

chem_info = pd.read_excel('/Users/yanlixu/Desktop/pingan/合作/CDK12/220616/1_breast_cancer_20220616.xlsx', sheet_name='selected_chemicals')
chem_info = chem_info.set_index('SignatureId')
chem_info
# Out:
#                 Unnamed: 0       Perturbagen  \
# SignatureId
# LINCSCP_33167           14  (+)-Camptothecin
# LINCSCP_240518          71         Linifanib
# LINCSCP_32012           92     CHEMBL2142321
# LINCSCP_34284          158      Camptothecin
# LINCSCP_238767         162       Ampiroxicam
# ...                    ...               ...
# LINCSCP_139188        5350            LGX818
# LINCSCP_30957         5364       221243-77-2
# LINCSCP_34739         5365          Guaiacol
# LINCSCP_132928        5374         GW843682X
# LINCSCP_30625         5381          ZM336372
#
#                                            GeneTargets Concentration CellLine  \
# SignatureId
# LINCSCP_33167                                     TOP1          10uM     MCF7
# LINCSCP_240518  CSF1R|FLT1|FLT3|FLT4|KDR|PDGFRA|PDGFRB          10uM     MCF7
# LINCSCP_32012                                      NaN          10uM     MCF7
# LINCSCP_34284                                     TOP1          10uM     MCF7
# LINCSCP_238767                             PTGS1|PTGS2          10uM     MCF7
# ...                                                ...           ...      ...
# LINCSCP_139188                                     NaN          10uM     MCF7
# LINCSCP_30957                                      NaN          10uM     MCF7
# LINCSCP_34739                                      NaN          10uM     MCF7
# LINCSCP_132928                               PLK1|PLK3        0.04uM     MCF7
# LINCSCP_30625                                      NaN         100uM     MCF7
#
#                 Tissue Time  is_exemplar  Concordance    pValue  nGenes
# SignatureId
# LINCSCP_33167   breast   6h          1.0     0.642109  0.000018      37
# LINCSCP_240518  breast   6h          1.0     0.604085  0.000075      37
# LINCSCP_32012   breast   6h          0.0     0.597943  0.000093      37
# LINCSCP_34284   breast  24h          0.0     0.581783  0.000159      37
# LINCSCP_238767  breast  24h          0.0     0.580579  0.000165      37
# ...                ...  ...          ...          ...       ...     ...
# LINCSCP_139188  breast  24h          NaN     0.418869  0.009871      37
# LINCSCP_30957   breast  24h          0.0     0.418638  0.009916      37
# LINCSCP_34739   breast   6h          1.0     0.418624  0.009919      37
# LINCSCP_132928  breast   3h          NaN     0.418537  0.009936      37
# LINCSCP_30625   breast  24h          0.0     0.418457  0.009952      37
#
# [429 rows x 11 columns]

# %%
df_final_w_chem_info = pd.merge(df_final, chem_info, left_index=True, right_index=True)
df_final_w_chem_info
# Out:
#                 percentage_of_same_direction_genes_w_33167  \
# LINCSCP_34265                                         0.24
# LINCSCP_140577                                        0.30
# LINCSCP_132948                                        0.30
# LINCSCP_34739                                         0.32
# LINCSCP_137401                                        0.35
# ...                                                    ...
# LINCSCP_31216                                         0.78
# LINCSCP_133897                                        0.73
# LINCSCP_33167                                         1.00
# LINCSCP_35120                                         0.84
# LINCSCP_240981                                        0.73
#
#                 percentage_of_reverse_direction_genes_w_breast_cancer  \
# LINCSCP_34265                                                0.54
# LINCSCP_140577                                               0.59
# LINCSCP_132948                                               0.59
# LINCSCP_34739                                                0.62
# LINCSCP_137401                                               0.65
# ...                                                           ...
# LINCSCP_31216                                                0.54
# LINCSCP_133897                                               0.49
# LINCSCP_33167                                                0.65
# LINCSCP_35120                                                0.54
# LINCSCP_240981                                               0.43
#
#                 rank_score  Unnamed: 0           Perturbagen GeneTargets  \
# LINCSCP_34265         2.25        1283         Ciprofloxacin         NaN
# LINCSCP_140577        1.97        3208               Betulin         NaN
# LINCSCP_132948        1.97        1569             Tamatinib         SYK
# LINCSCP_34739         1.94        5365              Guaiacol         NaN
# LINCSCP_137401        1.86        3350             GF-109203       PRKCA
# ...                    ...         ...                   ...         ...
# LINCSCP_31216         0.69        1435          MLS003128613         NaN
# LINCSCP_133897        0.67        4572              Ischemin         NaN
# LINCSCP_33167         0.65          14      (+)-Camptothecin        TOP1
# LINCSCP_35120         0.64        3839         BRD-K55260239         NaN
# LINCSCP_240981        0.59        3616  Olmesartan Medoxomil       AGTR1
#
#                Concentration CellLine  Tissue Time  is_exemplar  Concordance  \
# LINCSCP_34265           10uM     MCF7  breast  24h          0.0     0.500478
# LINCSCP_140577        0.06uM     MCF7  breast  24h          NaN     0.451236
# LINCSCP_132948        3.33uM     MCF7  breast   3h          NaN     0.490079
# LINCSCP_34739           10uM     MCF7  breast   6h          1.0     0.418624
# LINCSCP_137401        3.33uM     MCF7  breast  24h          NaN     0.448565
# ...                      ...      ...     ...  ...          ...          ...
# LINCSCP_31216           10uM     MCF7  breast  24h          1.0     0.494360
# LINCSCP_133897        1.11uM     MCF7  breast  24h          NaN     0.429444
# LINCSCP_33167           10uM     MCF7  breast   6h          1.0     0.642109
# LINCSCP_35120            5uM     MCF7  breast  24h          1.0     0.440102
# LINCSCP_240981          10uM     MCF7  breast   6h          0.0     0.443677
#
#                   pValue  nGenes
# LINCSCP_34265   0.001607      37
# LINCSCP_140577  0.005061      37
# LINCSCP_132948  0.002077      37
# LINCSCP_34739   0.009919      37
# LINCSCP_137401  0.005361      37
# ...                  ...     ...
# LINCSCP_31216   0.001871      37
# LINCSCP_133897  0.007991      37
# LINCSCP_33167   0.000018      37
# LINCSCP_35120   0.006414      37
# LINCSCP_240981  0.005949      37
#
# [429 rows x 14 columns]

# %%
df_final_w_chem_info.to_csv('drugcombination1.csv')

# %%
sns.scatterplot(data=df_final_w_chem_info, x="percentage_of_same_direction_genes_w_33167", y="percentage_of_reverse_direction_genes_w_breast_cancer")
plt.show()

# %%
df_final_w_chem_info_sorted = df_final_w_chem_info.sort_values(by='rank_score', ascending=False)
df_final_w_chem_info_sorted
# Out:
#                 percentage_of_same_direction_genes_w_33167  \
# LINCSCP_34265                                         0.24
# LINCSCP_132948                                        0.30
# LINCSCP_140577                                        0.30
# LINCSCP_34739                                         0.32
# LINCSCP_34367                                         0.35
# ...                                                    ...
# LINCSCP_31216                                         0.78
# LINCSCP_133897                                        0.73
# LINCSCP_33167                                         1.00
# LINCSCP_35120                                         0.84
# LINCSCP_240981                                        0.73
#
#                 percentage_of_reverse_direction_genes_w_breast_cancer  \
# LINCSCP_34265                                                0.54
# LINCSCP_132948                                               0.59
# LINCSCP_140577                                               0.59
# LINCSCP_34739                                                0.62
# LINCSCP_34367                                                0.65
# ...                                                           ...
# LINCSCP_31216                                                0.54
# LINCSCP_133897                                               0.49
# LINCSCP_33167                                                0.65
# LINCSCP_35120                                                0.54
# LINCSCP_240981                                               0.43
#
#                 rank_score  Unnamed: 0           Perturbagen GeneTargets  \
# LINCSCP_34265         2.25        1283         Ciprofloxacin         NaN
# LINCSCP_132948        1.97        1569             Tamatinib         SYK
# LINCSCP_140577        1.97        3208               Betulin         NaN
# LINCSCP_34739         1.94        5365              Guaiacol         NaN
# LINCSCP_34367         1.86        3020         Sulfacetamide         NaN
# ...                    ...         ...                   ...         ...
# LINCSCP_31216         0.69        1435          MLS003128613         NaN
# LINCSCP_133897        0.67        4572              Ischemin         NaN
# LINCSCP_33167         0.65          14      (+)-Camptothecin        TOP1
# LINCSCP_35120         0.64        3839         BRD-K55260239         NaN
# LINCSCP_240981        0.59        3616  Olmesartan Medoxomil       AGTR1
#
#                Concentration CellLine  Tissue Time  is_exemplar  Concordance  \
# LINCSCP_34265           10uM     MCF7  breast  24h          0.0     0.500478
# LINCSCP_132948        3.33uM     MCF7  breast   3h          NaN     0.490079
# LINCSCP_140577        0.06uM     MCF7  breast  24h          NaN     0.451236
# LINCSCP_34739           10uM     MCF7  breast   6h          1.0     0.418624
# LINCSCP_34367           10uM     MCF7  breast   6h          1.0     0.455240
# ...                      ...      ...     ...  ...          ...          ...
# LINCSCP_31216           10uM     MCF7  breast  24h          1.0     0.494360
# LINCSCP_133897        1.11uM     MCF7  breast  24h          NaN     0.429444
# LINCSCP_33167           10uM     MCF7  breast   6h          1.0     0.642109
# LINCSCP_35120            5uM     MCF7  breast  24h          1.0     0.440102
# LINCSCP_240981          10uM     MCF7  breast   6h          0.0     0.443677
#
#                   pValue  nGenes
# LINCSCP_34265   0.001607      37
# LINCSCP_132948  0.002077      37
# LINCSCP_140577  0.005061      37
# LINCSCP_34739   0.009919      37
# LINCSCP_34367   0.004638      37
# ...                  ...     ...
# LINCSCP_31216   0.001871      37
# LINCSCP_133897  0.007991      37
# LINCSCP_33167   0.000018      37
# LINCSCP_35120   0.006414      37
# LINCSCP_240981  0.005949      37
#
# [429 rows x 14 columns]

# %%
df_final_w_chem_info_sorted.to_csv('test0616.csv')

# %%
df_final_w_chem_info_sorted_sub = df_final_w_chem_info_sorted.loc[['LINCSCP_33167','LINCSCP_34265','LINCSCP_132948','LINCSCP_140577','LINCSCP_34739', 'LINCSCP_34367', 'LINCSCP_137401', 'LINCSCP_142518', 'LINCSCP_236972', 'LINCSCP_248968', 'LINCSCP_34392', 'LINCSCP_236234', 'LINCSCP_143067']]

x = df_final_w_chem_info_sorted_sub['percentage_of_same_direction_genes_w_33167'].values
y = df_final_w_chem_info_sorted_sub['percentage_of_reverse_direction_genes_w_breast_cancer'].values
samples = df_final_w_chem_info_sorted_sub['Perturbagen'].tolist()

fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(x, y)

ax.set_xlabel('percentage_of_same_direction_genes_w_33167', fontsize=14)
ax.set_ylabel('percentage_of_reverse_direction_genes_w_breast_cancer', fontsize=14)
ax.set_title('Top compounds combined with LINCSCP_33167', fontsize=18)

for i, txt in enumerate(samples):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='red')
plt.show()
